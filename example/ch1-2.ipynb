# %%
import os, sys
main_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))# この.ipynbファイルがあるディレクトリの一つ上の階層を指定(utilsフォルダがある階層)
sys.path.append(main_dir)
sys.path.append(os.path.join(main_dir, 'utils')) # utils内のppms.py, util_tr.pyをimportできるようにするため

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ppms
import util_tr as tr
import os.path
import importlib
importlib.reload(ppms)
importlib.reload(tr)

pwd = os.getcwd()
filepath_Hall = os.path.join(os.getcwd(),"4_Hall.dat") # 解析したいHallデータのパスを指定
filepath_RT = os.path.join(os.getcwd(),"1_RT.dat" ) # 解析したい抵抗率データのパスを指定
ch_num = [1,2] # 対応するPPMSパッケージの端子番号をリストで指定([縦端子,横端子])
sample_str = "#ch1-2" # サンプル名の文字列を指定 (#1000など)
thickness = 0 # 単位は[m] # 試料の厚さを指定。2次元試料の場合は0を指定
temp_threshold = 0.1 
save_raw = False


# 実行
ppms.analyze_Hall_multi_temps_ppms(filepath_Hall, ch_num, sample_str, thickness, temp_threshold, save_raw)
ppms.analyze_RT_ppms(filepath_RT, ch_num, sample_str, thickness)
