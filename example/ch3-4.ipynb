# %%
import os, sys
main_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(main_dir)
sys.path.append(os.path.join(main_dir, 'utils'))

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ppms
import util_tr as tr
import os.path
import importlib
importlib.reload(ppms)
importlib.reload(tr)

pwd = os.getcwd()
filepath_Hall = os.path.join(os.getcwd(),"4_Hall.dat")
filepath_RT = os.path.join(os.getcwd(),"1_RT.dat" )
ch_num = [3,4]
sample_str = "#ch3-4" 
thickness = 0 # 単位は[m]
temp_threshold = 0.1 
save_raw = False


# 実行
ppms.analyze_Hall_multi_temps_ppms(filepath_Hall, ch_num, sample_str, thickness, temp_threshold, save_raw)
ppms.analyze_RT_ppms(filepath_RT, ch_num, sample_str, thickness)
# Out:
# makedirs : c:\Users\kg315\Documents\GitHub_univ\PPMS-Analysis\example\#1138
